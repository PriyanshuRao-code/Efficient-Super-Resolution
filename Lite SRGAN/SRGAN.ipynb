# %% [markdown]
# # Start From here

# %%
# !sudo apt-get install python3.10 python3.10-venv python3.10-distutils -y

# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1
# !sudo update-alternatives --config python3

# !python3 -m ensurepip --upgrade
# !python3 -m pip install --upgrade pip setuptools wheel

# !python3 -m pip install tensorflow==2.9.1 keras==2.9.0 numpy==1.21.4 opencv-contrib-python==4.5.5
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'python3-distutils' instead of 'python3.10-distutils'
# python3-distutils is already the newest version (3.10.8-1~22.04).
# python3-distutils set to manually installed.
# python3.10 is already the newest version (3.10.12-1~22.04.11).
# python3.10 set to manually installed.
# The following NEW packages will be installed:
#   python3-pip-whl python3-setuptools-whl python3.10-venv
# 0 upgraded, 3 newly installed, 0 to remove and 41 not upgraded.
# Need to get 2,481 kB of archives.
# After this operation, 2,754 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip-whl all 22.0.2+dfsg-1ubuntu0.7 [1,683 kB]
# Get:2 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 python3-setuptools-whl all 68.1.2-2~jammy3 [792 kB]
# ...

# %%
# !pip install tensorflow

# %%
# !git clone https://github.com/vk8540002229-dev/LiteSRGAN-and-LiteUNet.git
# Out:
# Cloning into 'LiteSRGAN-and-LiteUNet'...
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 83 (delta 40), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (83/83), 23.53 MiB | 11.33 MiB/s, done.
# Resolving deltas: 100% (40/40), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/images_001/
# Out:
# original_images

# %%
# !python LiteSRGAN-and-LiteUNet/Lite-SRGAN/main.py
# Out:
# 2025-11-29 15:56:36.063470: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764431796.083355    1550 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764431796.089497    1550 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764431796.105363    1550 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# # END OF THE NOTEBOOK
